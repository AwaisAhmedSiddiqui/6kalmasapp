# %% [markdown]
# <a href="https://colab.research.google.com/github/AwaisAhmedSiddiqui/6kalmasapp/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the **Content Refresh Prioritization** lane because FlyRank's goal is to help identify which content pages should be refreshed first before their search performance declines. This project focuses on improving business decisions rather than simply training a model. Machine learning can help combine multiple search-performance signals to prioritize pages more effectively than a fixed rule.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision:** Which content pages should be refreshed first?
#
# **Who acts?** An SEO editor or content manager.
#
# **Action:** Refresh the highest-priority pages before they lose more search traffic.
#
# **Unit of analysis:** One content page.
#
# **Output:** A ranked priority score for each content page.
#
# **Task type:** Ranking / Scoring.
#
# **Success metric:** Precision@K, because the goal is to rank the most valuable pages near the top.
#
# **Cost of a wrong recommendation:** If the wrong pages are prioritized, editors waste time and resources while high-value pages continue to lose traffic and visibility.
#
# **Why machine learning helps:** Search performance depends on many interacting signals that are difficult to capture using simple hand-written rules. Machine learning can identify useful patterns to support better decisions.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains **30,000 rows** and **44 columns**.
#
# The dataset contains **32 anonymized clients**.
#
# The average CTR in the starter dataset is **0.xx%**.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision-support based on observed historical search data.
#
# The findings may identify useful patterns that help prioritize content refresh decisions, but they do not prove causal relationships.
#
# The model will not predict Google's ranking algorithm or guarantee future search performance.
#
# Any recommendations should be validated before being used in production.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
